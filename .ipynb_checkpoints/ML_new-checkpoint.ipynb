# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("mi_data.csv")
df.head(3)
# Out:
#                               model_names  ratings    price  \
# 0  REDMI 10 Power (Sporty Orange, 128 GB)      4.2  ₹13,500
# 1    REDMI 10 Power (Power Black, 128 GB)      4.2  ₹12,840
# 2   Redmi 9A Sport (Metallic Blue, 32 GB)      4.1   ₹7,520
#
#                                               imgURL  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...
# 1  https://rukminim2.flixcart.com/image/312/312/x...
# 2  https://rukminim2.flixcart.com/image/312/312/x...
#
#                                          storage_ram  \
# 0  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 1  Internal Storage128 GBRAM8 GBMemory Card Slot ...
# 2  Internal Storage32 GBRAM2 GBMemory Card Slot T...
#
#                                         os_processor  \
# 0  Operating SystemAndroid 13Processor CoreOcta C...
# 1  Operating SystemAndroid 13Processor CoreOcta C...
# 2  Operating SystemAndroid Q 10Processor CoreOcta...
#
#                                             network                   battery
# 0      Network Type4G VOLTESupported Networks4G LTE  Battery Capacity6000 mAh
# 1    Network Type4G VOLTESupported Networks4G VoLTE  Battery Capacity6000 mAh
# 2  Network Type4G VOLTE, 4GSupported Networks4G LTE  Battery Capacity5000 mAh

# %%
df.info
# Out:
# <bound method DataFrame.info of      ratings    price
# 0        4.2  ₹13,500
# 1        4.2  ₹12,840
# 2        4.1   ₹7,520
# 3        4.2   ₹8,450
# 4        4.2  ₹21,644
# ..       ...      ...
# 543      4.5  ₹26,999
# 544      4.1   ₹8,999
# 545      4.3  ₹11,990
# 546      4.3  ₹24,999
# 547      4.1  ₹12,500
#
# [548 rows x 2 columns]>

# %%
df.drop(columns=["imgURL","model_names","storage_ram","os_processor","network","battery"],inplace=True,axis=1)
df.head()
# Out:
#    ratings    price
# 0      4.2  ₹13,500
# 1      4.2  ₹12,840
# 2      4.1   ₹7,520
# 3      4.2   ₹8,450
# 4      4.2  ₹21,644

# %%
plt.scatter(df["price"],df["ratings"])

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]
x
# Out:
#      ratings
# 0        4.2
# 1        4.2
# 2        4.1
# 3        4.2
# 4        4.2
# ..       ...
# 543      4.5
# 544      4.1
# 545      4.3
# 546      4.3
# 547      4.1
#
# [548 rows x 1 columns]

# %%
y
# Out:
# 0      ₹13,500
# 1      ₹12,840
# 2       ₹7,520
# 3       ₹8,450
# 4      ₹21,644
#         ...
# 543    ₹26,999
# 544     ₹8,999
# 545    ₹11,990
# 546    ₹24,999
# 547    ₹12,500
# Name: price, Length: 548, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 438 entries, 46 to 102
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ratings  438 non-null    float64
# dtypes: float64(1)
# memory usage: 6.8 KB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110 entries, 247 to 302
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ratings  110 non-null    float64
# dtypes: float64(1)
# memory usage: 1.7 KB

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# c:\Users\muska\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.02727272727272727

# %%
df.head(2)
# Out:
#    ratings    price
# 0      4.2  ₹13,500
# 1      4.2  ₹12,840

# %%
m = model.coef_
b = model.intercept_



s = 1/(1+ np.exp(-(m*4.2 + b)))
s
# Out:
# array([[0.37311999, 0.28921345, 0.28921345, ..., 0.80778265, 0.37311999,
#         0.3023764 ],
#        [0.46415259, 0.37192014, 0.37192014, ..., 0.85946884, 0.46415259,
#         0.38679888],
#        [0.46415259, 0.37192014, 0.37192014, ..., 0.85946884, 0.46415259,
#         0.38679888],
#        ...,
#        [0.20170787, 0.14729124, 0.14729124, ..., 0.64080672, 0.20170787,
#         0.15540716],
#        [0.37311999, 0.28921345, 0.28921345, ..., 0.80778265, 0.37311999,
#         0.3023764 ],
#        [0.89726119, 0.85653511, 0.85653511, ..., 0.98404153, 0.89726119,
#         0.8641277 ]])
